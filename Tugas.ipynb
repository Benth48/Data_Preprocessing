# %% [markdown]
# <a href="https://colab.research.google.com/github/Benth48/Data_Preprocessing/blob/main/Tugas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv('https://raw.githubusercontent.com/Benth48/Data_Preprocessing/refs/heads/main/employee_data_company_type_1.csv')
data2=pd.read_csv('https://raw.githubusercontent.com/Benth48/Data_Preprocessing/refs/heads/main/employee_data_company_type_2.csv')
data3=pd.read_csv('https://raw.githubusercontent.com/Benth48/Data_Preprocessing/refs/heads/main/employee_data_company_type_3.csv')

# %%
data1
# Out:
#                 Name   Age                       Salary Department  \
# 0    Employee_v1_001   NaN  sixty-five hundred thousand         HR
# 1    Employee_v1_002  39.0                      5278735  Marketing
# 2    Employee_v1_003  30.0                          NaN    Finance
# 3    Employee_v1_004  30.0                      6931036  Marketing
# 4    Employee_v1_005   NaN                          NaN  Marketing
# ..               ...   ...                          ...        ...
# 495  Employee_v1_496  37.0  sixty-five hundred thousand         IT
# 496  Employee_v1_497  26.0                          NaN         HR
# 497  Employee_v1_498   NaN                      6781744         IT
# 498  Employee_v1_499   NaN                          NaN         HR
# 499  Employee_v1_500   NaN                      6139275         IT
#
#     Joined_Date Performance
# 0    2018-07-13        Poor
# 1    2016-09-08        Good
# 2    2017-11-10        Good
# 3    2022-11-04        Good
# ...
